# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#1
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

def reverse_linked_list(head):
    prev = None
    current = head
    while current:
        next_node = current.next
        current.next = prev
        prev = current
        current = next_node
    return prev

# Helper function to print the list
def print_list(node):
    while node:
        print(node.val, end=" -> " if node.next else "\n")
        node = node.next

# Example usage
head = ListNode(1, ListNode(2, ListNode(3, ListNode(4, ListNode(5)))))
print("Original list:")
print_list(head)

reversed_head = reverse_linked_list(head)
print("Reversed list:")
print_list(reversed_head)
# Out:
# Original list:
# 1 -> 2 -> 3 -> 4 -> 5
# Reversed list:
# 5 -> 4 -> 3 -> 2 -> 1

# %%
#2
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

def merge_two_lists(l1, l2):
    dummy = ListNode()
    current = dummy
    while l1 and l2:
        if l1.val < l2.val:
            current.next = l1
            l1 = l1.next
        else:
            current.next = l2
            l2 = l2.next
        current = current.next
    current.next = l1 if l1 else l2
    return dummy.next

# Helper function to print the list
def print_list(node):
    while node:
        print(node.val, end=" -> " if node.next else "\n")
        node = node.next

# Example usage
l1 = ListNode(1, ListNode(3, ListNode(5)))
l2 = ListNode(2, ListNode(4, ListNode(6)))
print("List 1:")
print_list(l1)
print("List 2:")
print_list(l2)

merged_head = merge_two_lists(l1, l2)
print("Merged list:")
print_list(merged_head)
# Out:
# List 1:
# 1 -> 3 -> 5
# List 2:
# 2 -> 4 -> 6
# Merged list:
# 1 -> 2 -> 3 -> 4 -> 5 -> 6

# %%
#3
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

def remove_nth_from_end(head, n):
    dummy = ListNode(0, head)
    first = dummy
    second = dummy
    for _ in range(n + 1):
        first = first.next
    while first:
        first = first.next
        second = second.next
    second.next = second.next.next
    return dummy.next

# Helper function to print the list
def print_list(node):
    while node:
        print(node.val, end=" -> " if node.next else "\n")
        node = node.next

# Example usage
head = ListNode(1, ListNode(2, ListNode(3, ListNode(4, ListNode(5)))))
n = 2
print("Original list:")
print_list(head)

updated_head = remove_nth_from_end(head, n)
print(f"List after removing {n}th node from the end:")
print_list(updated_head)
# Out:
# Original list:
# 1 -> 2 -> 3 -> 4 -> 5
# List after removing 2th node from the end:
# 1 -> 2 -> 3 -> 5

# %%
#4
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

def get_intersection_node(headA, headB):
    if not headA or not headB:
        return None
    p1, p2 = headA, headB
    while p1 != p2:
        p1 = p1.next if p1 else headB
        p2 = p2.next if p2 else headA
    return p1

# Helper function to print the list
def print_list(node):
    while node:
        print(node.val, end=" -> " if node.next else "\n")
        node = node.next

# Example usage
intersect = ListNode(3, ListNode(4))
headA = ListNode(1, ListNode(2, intersect))
headB = ListNode(9, ListNode(8, intersect))
print("List 1:")
print_list(headA)
print("List 2:")
print_list(headB)

intersection = get_intersection_node(headA, headB)
if intersection:
    print(f"The intersection node's value is: {intersection.val}")
else:
    print("There is no intersection.")
# Out:
# List 1:
# 1 -> 2 -> 3 -> 4
# List 2:
# 9 -> 8 -> 3 -> 4
# The intersection node's value is: 3

# %%
#5
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

def remove_duplicates(head):
    current = head
    while current and current.next:
        if current.val == current.next.val:
            current.next = current.next.next
        else:
            current = current.next
    return head

# Helper function to print the list
def print_list(node):
    while node:
        print(node.val, end=" -> " if node.next else "\n")
        node = node.next

# Example usage
head = ListNode(1, ListNode(1, ListNode(2, ListNode(3, ListNode(3)))))
print("Original list:")
print_list(head)

updated_head = remove_duplicates(head)
print("List after removing duplicates:")
print_list(updated_head)
# Out:
# Original list:
# 1 -> 1 -> 2 -> 3 -> 3
# List after removing duplicates:
# 1 -> 2 -> 3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#6
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

def add_two_numbers(l1, l2):
    dummy_head = ListNode()
    current = dummy_head
    carry = 0

    while l1 or l2 or carry:
        val1 = l1.val if l1 else 0
        val2 = l2.val if l2 else 0

        # Calculate the sum and update the carry
        total = val1 + val2 + carry
        carry = total // 10
        current.next = ListNode(total % 10)

        # Move to the next nodes
        current = current.next
        if l1:
            l1 = l1.next
        if l2:
            l2 = l2.next

    return dummy_head.next

# Helper function to print the list
def print_list(node):
    while node:
        print(node.val, end=" -> " if node.next else "\n")
        node = node.next

# Example usage
l1 = ListNode(2, ListNode(4, ListNode(3)))
l2 = ListNode(5, ListNode(6, ListNode(4)))
print("List 1:")
print_list(l1)
print("List 2:")
print_list(l2)

result = add_two_numbers(l1, l2)
print("Resultant list:")
print_list(result)
# Out:
# List 1:
# 2 -> 4 -> 3
# List 2:
# 5 -> 6 -> 4
# Resultant list:
# 7 -> 0 -> 8

# %%
#7
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

def swap_pairs(head):
    dummy = ListNode(0)
    dummy.next = head
    current = dummy

    while current.next and current.next.next:
        first = current.next
        second = current.next.next

        first.next = second.next
        second.next = first
        current.next = second

        current = first

    return dummy.next

# Helper function to print the list
def print_list(node):
    while node:
        print(node.val, end=" -> " if node.next else "\n")
        node = node.next

# Example usage
head = ListNode(1, ListNode(2, ListNode(3, ListNode(4))))
print("Original list:")
print_list(head)

swapped_head = swap_pairs(head)
print("List after swapping pairs:")
print_list(swapped_head)
# Out:
# Original list:
# 1 -> 2 -> 3 -> 4
# List after swapping pairs:
# 2 -> 1 -> 4 -> 3

# %%
#8
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

def reverse_k_group(head, k):
    # Check if we have at least k nodes left in the list
    count = 0
    node = head
    while node and count < k:
        node = node.next
        count += 1

    if count == k:
        # Reverse the first k nodes
        prev = None
        current = head
        for _ in range(k):
            next_node = current.next
            current.next = prev
            prev = current
            current = next_node

        # Recursively call on the remaining list
        head.next = reverse_k_group(current, k)
        return prev
    return head

# Helper function to print the list
def print_list(node):
    while node:
        print(node.val, end=" -> " if node.next else "\n")
        node = node.next

# Example usage
head = ListNode(1, ListNode(2, ListNode(3, ListNode(4, ListNode(5)))))
k = 3
print("Original list:")
print_list(head)

reversed_head = reverse_k_group(head, k)
print(f"List after reversing in groups of {k}:")
print_list(reversed_head)
# Out:
# Original list:
# 1 -> 2 -> 3 -> 4 -> 5
# List after reversing in groups of 3:
# 3 -> 2 -> 1 -> 4 -> 5

# %%
#9
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

def is_palindrome(head):
    # Fast and slow pointer to find the middle of the list
    fast = slow = head
    prev = None

    # Reverse the first half of the list while finding the middle
    while fast and fast.next:
        fast = fast.next.next
        next_node = slow.next
        slow.next = prev
        prev = slow
        slow = next_node

    # If the list has odd number of elements, move slow one step further
    if fast:
        slow = slow.next

    # Compare the reversed first half with the second half
    while prev and slow:
        if prev.val != slow.val:
            return False
        prev = prev.next
        slow = slow.next

    return True

# Helper function to print the list
def print_list(node):
    while node:
        print(node.val, end=" -> " if node.next else "\n")
        node = node.next

# Example usage
head = ListNode(1, ListNode(2, ListNode(2, ListNode(1))))
print("Original list:")
print_list(head)

result = is_palindrome(head)
print(f"Is the list a palindrome? {result}")
# Out:
# Original list:
# 1 -> 2 -> 2 -> 1
# Is the list a palindrome? True

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#10
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

def rotate_right(head, k):
    if not head or not head.next or k == 0:
        return head

    # Find the length of the list and the last node
    length = 1
    last_node = head
    while last_node.next:
        last_node = last_node.next
        length += 1

    # Connect the last node to the head to form a circular list
    last_node.next = head

    # Find the new tail: (length - k % length - 1)th node
    # and the new head: (length - k % length)th node
    k = k % length
    steps_to_new_head = length - k

    new_tail = head
    for _ in range(steps_to_new_head - 1):
        new_tail = new_tail.next

    new_head = new_tail.next
    new_tail.next = None

    return new_head

# Helper function to print the list
def print_list(node):
    while node:
        print(node.val, end=" -> " if node.next else "\n")
        node = node.next

# Example usage
head = ListNode(1, ListNode(2, ListNode(3, ListNode(4, ListNode(5)))))
k = 2
print("Original list:")
print_list(head)

rotated_head = rotate_right(head, k)
print("Rotated list:")
print_list(rotated_head)
# Out:
# Original list:
# 1 -> 2 -> 3 -> 4 -> 5
# Rotated list:
# 4 -> 5 -> 1 -> 2 -> 3

# %%
#11
class Node:
    def __init__(self, val=None, next=None, prev=None, child=None):
        self.val = val
        self.next = next
        self.prev = prev
        self.child = child

def flatten(head):
    if not head:
        return head

    dummy = Node(0)
    dummy.next = head
    prev = dummy

    stack = []
    current = head

    while current:
        if current.child:
            if current.next:
                stack.append(current.next)
            current.next = current.child
            current.child.prev = current
            current.child = None

        prev = current
        current = current.next

        if not current and stack:
            current = stack.pop()
            prev.next = current
            current.prev = prev

    dummy.next.prev = None
    return dummy.next

# Helper function to print the list
def print_doubly_linked_list(node):
    while node:
        print(node.val, end=" <-> " if node.next else "\n")
        node = node.next

# Example usage
# Creating the multilevel doubly linked list as per the problem statement
head = Node(1, Node(2, Node(3, Node(4, Node(5, Node(6))))))
head.next.next.child = Node(7, Node(8, Node(9, Node(10))))
head.next.next.child.child = Node(11, Node(12))

print("Original list:")
print_doubly_linked_list(head)

flattened_head = flatten(head)
print("Flattened list:")
print_doubly_linked_list(flattened_head)
# Out:
# Original list:
# 1 <-> 2 <-> 3 <-> 4 <-> 5 <-> 6
# Flattened list:
# 1 <-> 2 <-> 3 <-> 7 <-> 11 <-> 12 <-> 8 <-> 9 <-> 10 <-> 4 <-> 5 <-> 6

# %%
#12
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

def rearrange_even_odd(head):
    if not head or not head.next:
        return head

    odd = head
    even = head.next
    even_head = even

    while even and even.next:
        odd.next = even.next
        odd = odd.next
        even.next = odd.next
        even = even.next

    odd.next = even_head
    return head

# Helper function to print the list
def print_list(node):
    while node:
        print(node.val, end=" -> " if node.next else "\n")
        node = node.next

# Example usage
head = ListNode(1, ListNode(2, ListNode(3, ListNode(4, ListNode(5)))))
print("Original list:")
print_list(head)

rearranged_head = rearrange_even_odd(head)
print("Rearranged list:")
print_list(rearranged_head)
# Out:
# Original list:
# 1 -> 2 -> 3 -> 4 -> 5
# Rearranged list:
# 1 -> 3 -> 5 -> 2 -> 4

# %%
#13
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

def add_one(head):
    def reverse_list(node):
        prev = None
        while node:
            next_node = node.next
            node.next = prev
            prev = node
            node = next_node
        return prev

    head = reverse_list(head)
    current = head
    carry = 1

    while current and carry:
        current.val += carry
        carry = current.val // 10
        current.val %= 10
        prev = current
        current = current.next

    if carry:
        prev.next = ListNode(carry)

    return reverse_list(head)

# Helper function to print the list
def print_list(node):
    while node:
        print(node.val, end=" -> " if node.next else "\n")
        node = node.next

# Example usage
head = ListNode(1, ListNode(2, ListNode(3)))  # Represents the number 123
print("Original number represented as list:")
print_list(head)

result_head = add_one(head)
print("Number after adding one:")
print_list(result_head)
# Out:
# Original number represented as list:
# 1 -> 2 -> 3
# Number after adding one:
# 1 -> 2 -> 4

# %%
#14
def search_insert(nums, target):
    left, right = 0, len(nums) - 1

    while left <= right:
        mid = (left + right) // 2
        if nums[mid] == target:
            return mid
        elif nums[mid] < target:
            left = mid + 1
        else:
            right = mid - 1

    return left

# Example usage
nums = [1, 3, 5, 6]
target = 5
print(f"Index of target {target} or insertion point: {search_insert(nums, target)}")

target = 2
print(f"Index of target {target} or insertion point: {search_insert(nums, target)}")
# Out:
# Index of target 5 or insertion point: 2
# Index of target 2 or insertion point: 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#15
def find_min_in_rotated_array(nums):
    left, right = 0, len(nums) - 1

    while left < right:
        mid = (left + right) // 2
        if nums[mid] > nums[right]:
            left = mid + 1
        else:
            right = mid

    return nums[left]

# Example usage
nums = [4, 5, 6, 7, 0, 1, 2]
print(f"The minimum element in the rotated array is: {find_min_in_rotated_array(nums)}")
# Out:
# The minimum element in the rotated array is: 0

# %%
#16
def search_in_rotated_array(nums, target):
    left, right = 0, len(nums) - 1

    while left <= right:
        mid = (left + right) // 2
        if nums[mid] == target:
            return mid
        # Check if the left half is sorted
        if nums[left] <= nums[mid]:
            if nums[left] <= target < nums[mid]:
                right = mid - 1
            else:
                left = mid + 1
        # Otherwise, the right half must be sorted
        else:
            if nums[mid] < target <= nums[right]:
                left = mid + 1
            else:
                right = mid - 1

    return -1

# Example usage
nums = [4, 5, 6, 7, 0, 1, 2]
target = 0
print(f"Index of target {target} in the rotated array: {search_in_rotated_array(nums, target)}")
# Out:
# Index of target 0 in the rotated array: 4

# %%
#17
def find_peak_element(nums):
    left, right = 0, len(nums) - 1

    while left < right:
        mid = (left + right) // 2
        if nums[mid] > nums[mid + 1]:
            right = mid
        else:
            left = mid + 1

    return left

# Example usage
nums = [1, 2, 3, 1]
print(f"The index of the peak element is: {find_peak_element(nums)}")
# Out:
# The index of the peak element is: 2

# %%
#18
def count_negatives(grid):
    count = 0
    for row in grid:
        for num in row:
            if num < 0:
                count += 1
    return count

# Optimized version using the property that each row and column is sorted
def count_negatives_optimized(grid):
    count = 0
    n, m = len(grid), len(grid[0])
    i, j = n - 1, 0

    while i >= 0 and j < m:
        if grid[i][j] < 0:
            count += m - j
            i -= 1
        else:
            j += 1

    return count

# Example usage
grid = [
    [4, 3, 2, -1],
    [3, 2, 1, -1],
    [1, 1, -1, -2],
    [-1, -1, -2, -3]
]
print(f"Number of negative numbers in the grid: {count_negatives_optimized(grid)}")
# Out:
# Number of negative numbers in the grid: 8

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#19
def search_matrix(matrix, target):
    if not matrix:
        return False

    rows, cols = len(matrix), len(matrix[0])
    left, right = 0, rows * cols - 1

    while left <= right:
        mid = (left + right) // 2
        mid_value = matrix[mid // cols][mid % cols]

        if mid_value == target:
            return True
        elif mid_value < target:
            left = mid + 1
        else:
            right = mid - 1

    return False

# Example usage
matrix = [
    [1, 3, 5, 7],
    [10, 11, 16, 20],
    [23, 30, 34, 60]
]
target = 3
print(f"Is target {target} present in the matrix? {search_matrix(matrix, target)}")
# Out:
# Is target 3 present in the matrix? True

# %%
#20
def find_median_sorted_arrays(nums1, nums2):
    nums = sorted(nums1 + nums2)
    n = len(nums)

    if n % 2 == 1:
        return float(nums[n // 2])
    else:
        return (nums[n // 2 - 1] + nums[n // 2]) / 2

# Example usage
nums1 = [1, 3]
nums2 = [2]
print(f"The median of the combined sorted arrays is: {find_median_sorted_arrays(nums1, nums2)}")
# Out:
# The median of the combined sorted arrays is: 2.0

# %%
#21
def next_greatest_letter(letters, target):
    for letter in letters:
        if letter > target:
            return letter
    return letters[0]  # wrap around

# Example usage
letters = ['c', 'f', 'j']
target = 'a'
print(f"The smallest letter greater than '{target}' is: {next_greatest_letter(letters, target)}")
# Out:
# The smallest letter greater than 'a' is: c

# %%
#22
def sort_colors(nums):
    low, mid, high = 0, 0, len(nums) - 1

    while mid <= high:
        if nums[mid] == 0:  # red
            nums[low], nums[mid] = nums[mid], nums[low]
            low += 1
            mid += 1
        elif nums[mid] == 1:  # white
            mid += 1
        else:  # blue
            nums[high], nums[mid] = nums[mid], nums[high]
            high -= 1

# Example usage
nums = [2, 0, 2, 1, 1, 0]
sort_colors(nums)
print(f"Sorted colors array: {nums}")
# Out:
# Sorted colors array: [0, 0, 1, 1, 2, 2]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#23
import heapq

def find_kth_largest(nums, k):
    return heapq.nlargest(k, nums)[-1]

# Example usage
nums = [3, 2, 1, 5, 6, 4]
k = 2
print(f"The {k}th largest element in the array is: {find_kth_largest(nums, k)}")
# Out:
# The 2th largest element in the array is: 5

# %%
#24
def wiggle_sort(nums):
    for i in range(len(nums) - 1):
        if (i % 2 == 0 and nums[i] > nums[i + 1]) or (i % 2 == 1 and nums[i] < nums[i + 1]):
            nums[i], nums[i + 1] = nums[i + 1], nums[i]

# Example usage
nums = [3, 5, 2, 1, 6, 4]
wiggle_sort(nums)
print(f"Wiggle sorted array: {nums}")
# Out:
# Wiggle sorted array: [3, 5, 1, 6, 2, 4]

# %%
#25
def sum_of_array(nums):
    return sum(nums)

# Example usage
nums = [1, 2, 3, 4, 5]
print(f"The sum of all elements in the array is: {sum_of_array(nums)}")
# Out:
# The sum of all elements in the array is: 15

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#26
def find_max(nums):
    return max(nums)

# Example usage
nums = [3, 7, 2, 9, 4, 1]
print(f"The maximum element in the array is: {find_max(nums)}")
# Out:
# The maximum element in the array is: 9

# %%
#27
def linear_search(nums, target):
    for index, value in enumerate(nums):
        if value == target:
            return index
    return -1

# Example usage
nums = [5, 3, 8, 2, 7, 4]
target = 8
print(f"The index of the target {target} is: {linear_search(nums, target)}")
# Out:
# The index of the target 8 is: 2

# %%
#28
def factorial(n):
    if n == 0:
        return 1
    else:
        return n * factorial(n - 1)

# Example usage
n = 5
print(f"The factorial of {n} is: {factorial(n)}")
# Out:
# The factorial of 5 is: 120

# %%
#29
def is_prime(n):
    if n <= 1:
        return False
    if n <= 3:
        return True
    if n % 2 == 0 or n % 3 == 0:
        return False
    i = 5
    while i * i <= n:
        if n % i == 0 or n % (i + 2) == 0:
            return False
        i += 6
    return True

# Example usage
n = 7
print(f"Is {n} a prime number? {is_prime(n)}")
# Out:
# Is 7 a prime number? True

# %%
#30
def fibonacci(n):
    fib_series = []
    a, b = 0, 1
    while len(fib_series) < n:
        fib_series.append(a)
        a, b = b, a + b
    return fib_series

# Example usage
n = 8
print(f"The Fibonacci series up to {n} elements is: {fibonacci(n)}")
# Out:
# The Fibonacci series up to 8 elements is: [0, 1, 1, 2, 3, 5, 8, 13]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#31
def power(base, exponent):
    if exponent == 0:
        return 1
    return base * power(base, exponent - 1)

# Example usage
base = 3
exponent = 4
print(f"{base} raised to the power of {exponent} is: {power(base, exponent)}")
# Out:
# 3 raised to the power of 4 is: 81

# %%
#32
def reverse_string(s):
    if len(s) == 0:
        return s
    return reverse_string(s[1:]) + s[0]

# Example usage
s = "hello"
print(f"The reverse of the string '{s}' is: '{reverse_string(s)}'")
# Out:
# The reverse of the string 'hello' is: 'olleh'
